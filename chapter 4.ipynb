# %%
print("The linear model prediction vectorized form is :")

# %%
import matplotlib.pyplot as plt
a = r'\hat{y} = h_{\theta} = \theta^{T} * x'
ax = plt.axes([0,0,0.3,0.3]) #left,bottom,width,height
ax.set_xticks([])
ax.set_yticks([])
ax.axis('off')
plt.text(0.4,0.4,'$%s$' %a,size=30,color="green")
# Out:
# Text(0.4, 0.4, '$\\hat{y} = h_{\\theta} = \\theta^{T} * x$')

# %%
print("ŷ is the predicted value.\n\
θ is the model’s parameter vector, containing the bias term θ0 and the feature weights θ1 to θn.\n\
x is the instance’s feature vector, containing x0 to xn, with x0 always equal to 1.\n\
θ · x is the dot product of the vectors θ and x, which is of course equal to θ0x0 + θ1x1 + θ2x2 + ... + θnxn.\n\
hθ is the hypothesis function, using the model parameters θ.")
# Out:
# ŷ is the predicted value.
# θ is the model’s parameter vector, containing the bias term θ0 and the feature weights θ1 to θn.
# x is the instance’s feature vector, containing x0 to xn, with x0 always equal to 1.
# θ · x is the dot product of the vectors θ and x, which is of course equal to θ0x0 + θ1x1 + θ2x2 + ... + θnxn.
# hθ is the hypothesis function, using the model parameters θ.

# %%
print("The Mean Square Error is :")
# Out:
# The Mean Square Error is :

# %%
import matplotlib.pyplot as plt
a = r'MSE(X, h_{\theta}) = \frac{1}{m}\sum_{i=1}^{m} (\theta^{T} x^{(i)} - y^{(i)})^2'
ax = plt.axes([0,0,0.3,0.3]) #left,bottom,width,height
ax.set_xticks([])
ax.set_yticks([])
ax.axis('off')
plt.text(0.4,0.4,'$%s$' %a,size=30,color="green")
# Out:
# Text(0.4, 0.4, '$MSE(X, h_{\\theta}) = \\frac{1}{m}\\sum_{i=1}^{m} (\\theta^{T} x^{(i)} - y^{(i)})^2$')

# %%
print("We want to minimize the value of θ",
      "\nWe can do this using the Normal equation",
      "\nThe Normal equation is the closed-form solution",
      "The Normal equation is:")
# Out:
# We want to minimize the value of θ
# We can do this using the Normal equation
# The Normal equation is the closed-form solution The Normal equation is:

# %%
import matplotlib.pyplot as plt
a = r'\hat{\theta} =(x^{T} x)^{-1} x^{T}y'
ax = plt.axes([0,0,0.3,0.3]) #left,bottom,width,height
ax.set_xticks([])
ax.set_yticks([])
ax.axis('off')
plt.text(0.4,0.4,'$%s$' %a,size=30,color="green")
# Out:
# Text(0.4, 0.4, '$\\hat{\\theta} =(x^{T} x)^{-1} x^{T}y$')

# %%
print("θˆ is the value of θ that minimizes the cost function.",
      "\ny is the vector of target values containing y(1) to y(m).")
# Out:
# θˆ is the value of θ that minimizes the cost function.
# y is the vector of target values containing y(1) to y(m).

# %%
print("Make some linear looking data")
# Out:
# Make some linear looking data

# %%
import numpy as np

X = 2 * np.random.rand(100, 1)
y = 4 + 3 * X + np.random.randn(100, 1)

# %%
plt.scatter(X, y, c="b", alpha=0.5,)
plt.xlabel("X")
plt.ylabel("Y")
# Out:
# Text(0, 0.5, 'Y')

# %%
#concatenate a column of 1's with X 
X_b = np.c_[np.ones((100, 1)), X]  # add x0 = 1 to each instance

#use the normal equation to find the optimized theta
theta_best = np.linalg.inv(X_b.T.dot(X_b)).dot(X_b.T).dot(y)

# %%
print(theta_best)
# Out:
# [[3.9512125 ]
#  [2.99039124]]

# %%
X_new = np.array([[0], [2]])
X_new_b = np.c_[np.ones((2, 1)), X_new] # add x0 = 1 to each instance

# %%
print(X_new_b)
# Out:
# [[1. 0.]
#  [1. 2.]]

# %%
y_predict = X_new_b.dot(theta_best)

# %%
y_predict
# Out:
# array([[3.9512125 ],
#        [9.93199498]])

# %%
plt.plot(X_new, y_predict, "r-")
plt.plot(X, y, "b.")
plt.axis([0, 2, 0, 15])
plt.show()

# %%
print("linear regression")
# Out:
# linear regression

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X, y)
print("Linear Regression intercept", lin_reg.intercept_, "Linear coefficients", lin_reg.coef_)
# Out:
# Linear Regression intercept [3.9512125] Linear coefficients [[2.99039124]]

# %%
lin_reg.predict(X_new)
# Out:
# array([[3.9512125 ],
#        [9.93199498]])

# %%
#or you could use the class that the linear regression model is made after
theta_best_svd, residuals, rank, s = np.linalg.lstsq(X_b, y, rcond=1e-6)
theta_best_svd
# Out:
# array([[3.9512125 ],
#        [2.99039124]])

# %%
print("Or you can use np.linalg.pinv, which uses Moore-Penrose inverse")
print("The Moore-Penrose inverse can be used instead of the Normal equation",
      "The Moore-Penrose equation can be used when a matrix is non-invertible")
# Out:
# Or you can use np.linalg.pinv, which uses Moore-Penrose inverse
# The Moore-Penrose inverse can be used instead of the Normal equation The Moore-Penrose equation can be used when a matrix is non-invertible

# %%
np.linalg.pinv(X_b).dot(y)
# Out:
# array([[3.9512125 ],
#        [2.99039124]])

# %%
print("The normal equation has a computational complexity of between O(n^2) and O(n^3)")
# Out:
# The normal equation has a computational complexity of between O(n^2) and O(n^3)

# %%
print("When using gradient descent features should be scaled similarly if they are going to converge quicker")
# Out:
# When using gradient descent features should be scaled similarly if they are going to converge quicker

# %%
print("The partial derivatives of the cost function calculation")
# Out:
# The partial derivatives of the cost function calculation

# %%
import matplotlib.pyplot as plt
a = r'\frac{\sigma}{\sigma\theta_j} MSE({\theta}) = \frac{2}{m}\sum_{i=1}^{m} (\theta^{T} x^{(i)} - y^{(i)})x_j^{(i)}'
ax = plt.axes([0,0,0.3,0.3]) #left,bottom,width,height
ax.set_xticks([])
ax.set_yticks([])
ax.axis('off')
plt.text(0.4,0.4,'$%s$' %a,size=30,color="green")
# Out:
# Text(0.4, 0.4, '$\\frac{\\sigma}{\\sigma\\theta_j} MSE({\\theta}) = \\frac{2}{m}\\sum_{i=1}^{m} (\\theta^{T} x^{(i)} - y^{(i)})x_j^{(i)}$')

# %%
print("The vectorized version is ")
# Out:
# The vectorized version is

# %%
import matplotlib.pyplot as plt
a = r'\nabla MSE({\theta}) = \frac{2}{m} x^{T} (x \theta- y)'
ax = plt.axes([0,0,0.3,0.3]) #left,bottom,width,height
ax.set_xticks([])
ax.set_yticks([])
ax.axis('off')
plt.text(0.4,0.4,'$%s$' %a,size=30,color="green")
# Out:
# Text(0.4, 0.4, '$\\nabla MSE({\\theta}) = \\frac{2}{m} x^{T} (x \\theta- y)$')

# %%
print("Gradient Descent Step")
# Out:
# Gradient Descent Step

# %%
import matplotlib.pyplot as plt
a = r'\theta^{(next step)} =  \theta - \eta \nabla_{\theta} MSE(\theta)'
ax = plt.axes([0,0,0.3,0.3]) #left,bottom,width,height
ax.set_xticks([])
ax.set_yticks([])
ax.axis('off')
plt.text(0.4,0.4,'$%s$' %a,size=30,color="green")
# Out:
# Text(0.4, 0.4, '$\\theta^{(next step)} =  \\theta - \\eta \\nabla_{\\theta} MSE(\\theta)$')

# %%
eta = 0.1  # learning rate
n_iterations = 10
m = 100

theta = np.random.randn(2,1)  # random initialization

for iteration in range(n_iterations):
    gradients = 2/m * X_b.T.dot(X_b.dot(theta) - y)
    theta = theta - eta * gradients
    print("\n\nTheta ", theta)
    print("\n\nGradient",gradients)
# Out:
# Theta  [[1.09698465]
#  [2.22660835]]
#
#
# Gradient [[-12.4398714 ]
#  [-13.71344285]]
#
#
# Theta  [[1.81962764]
#  [2.99306654]]
#
#
# Gradient [[-7.22642989]
#  [-7.6645819 ]]
#
#
# Theta  [[2.24541291]
#  [3.41600894]]
#
#
# Gradient [[-4.25785271]
#  [-4.22942401]]
#
#
# Theta  [[2.50198378]
#  [3.64402429]]
#
#
# Gradient [[-2.56570868]
#  [-2.28015351]]
#
#
# Theta  [[2.66192375]
#  [3.76158055]]
#
#
# Gradient [[-1.59939966]
#  [-1.17556264]]
#
#
# Theta  [[2.76651209]
#  [3.81669064]]
#
#
# Gradient [[-1.04588347]
#  [-0.55110083]]
#
#
# Theta  [[2.83922996]
#  [3.83664151]]
#
#
# Gradient [[-0.72717868]
#  [-0.19950875]]
#
#
# Theta  [[2.89343913]
#  [3.83693688]]
#
#
# Gradient [[-0.54209174]
#  [-0.0029537 ]]
#
#
# Theta  [[2.93674777]
#  [3.82638146]]
#
#
# Gradient [[-0.43308636]
#  [ 0.10555423]]
#
#
# Theta  [[2.97349251]
#  [3.80997158]]
#
#
# Gradient [[-0.36744738]
#  [ 0.16409876]]

# %%
print(theta)
# Out:
# [[2.97349251]
#  [3.80997158]]

# %%
#eventually I want to show how the gradient changes over 10 iterations
plt.plot(X, y, "b.")
plt.axis([0, 2, 0, 15])
plt.show()

# %%
print("Stochastic Gradient Descent")
# Out:
# Stochastic Gradient Descent

# %%
n_epochs = 50
t0, t1 = 5, 50  # learning schedule hyperparameters

def learning_schedule(t):
    return t0 / (t + t1)

theta = np.random.randn(2,1)  # random initialization

for epoch in range(n_epochs):
    for i in range(m):
        random_index = np.random.randint(m)
        xi = X_b[random_index:random_index+1]
        yi = y[random_index:random_index+1]
        gradients = 2 * xi.T.dot(xi.dot(theta) - yi)
        eta = learning_schedule(epoch * m + i)
        theta = theta - eta * gradients

# %%
from sklearn.linear_model import SGDRegressor
sgd_reg = SGDRegressor(max_iter=1000, tol=1e-3, penalty=None, eta0=0.1)
sgd_reg.fit(X, y.ravel())
# Out:
# SGDRegressor(alpha=0.0001, average=False, early_stopping=False, epsilon=0.1,
#              eta0=0.1, fit_intercept=True, l1_ratio=0.15,
#              learning_rate='invscaling', loss='squared_loss', max_iter=1000,
#              n_iter_no_change=5, penalty=None, power_t=0.25, random_state=None,
#              shuffle=True, tol=0.001, validation_fraction=0.1, verbose=0,
#              warm_start=False)

# %%
 sgd_reg.intercept_, sgd_reg.coef_
# Out:
# (array([3.98127496]), array([3.02727437]))

# %%
print("polynomial regression")
# Out:
# polynomial regression

# %%
m = 1000
X = 6 * np.random.rand(m, 1) - 3
y = 0.5 * X**2 + X + 2 + np.random.randn(m, 1)

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_features = PolynomialFeatures(degree=2, include_bias=False)
X_poly = poly_features.fit_transform(X)
X[0]
# Out:
# array([-0.31140248])

# %%
X_poly[0]
# Out:
# array([-0.31140248,  0.09697151])

# %%
plt.plot(X, y, "b.")
plt.axis([-3, 3, 0, 10])
plt.show()

# %%
lin_reg = LinearRegression()
lin_reg.fit(X_poly, y)
lin_reg.intercept_, lin_reg.coef_
# Out:
# (array([2.05261264]), array([[0.97979051, 0.50166276]]))

# %%
y_hat = lin_reg.coef_.T

# %%
print("coef shape", lin_reg.coef_.shape)
print("X_poly shape", X_poly.shape)
print(X_poly.dot(lin_reg.coef_.T)+lin_reg.intercept_)
# Out:
# coef shape (1, 2)
# X_poly shape (1000, 2)
# [[1.79615044]
#  [4.13246995]
#  [2.55917163]
#  [9.46865159]
#  [2.57781383]
#  [1.74584036]
#  [8.38854112]
#  [4.71547317]
#  [3.07712933]
#  [6.19499735]
#  [2.08809549]
#  [2.11732598]
#  [1.59230333]
#  [1.83811399]
#  [5.42674919]
#  [1.58370966]
#  [5.88498674]
#  [2.63800717]
#  [4.13231041]
#  [1.90284687]
#  [2.05297611]
#  [1.6055706 ]
#  [1.7959617 ]
#  [2.76235919]
#  [1.90621622]
#  [1.89307059]
#  [1.96707173]
#  [6.16519448]
#  [3.09562368]
#  [3.52727839]
#  [1.57446704]
#  [5.44715791]
#  [6.72437532]
#  [5.30740788]
#  [3.16499068]
#  [2.25904384]
#  [1.57630113]
#  [2.68799802]
#  [3.5590106 ]
#  [1.76712721]
#  [6.66701149]
#  [1.59572663]
#  [2.20745446]
#  [3.29653441]
#  [8.37651477]
#  [4.80325915]
#  [1.65272644]
#  [1.60725928]
#  [4.17726123]
#  [3.04355125]
#  [2.56460243]
#  [5.53572839]
#  [8.66010371]
#  [6.26506412]
#  [2.77975129]
#  [3.34130158]
#  [4.75393866]
#  [2.0819143 ]
#  [1.57514455]
#  [2.04294423]
#  [2.50030091]
#  [6.83726214]
#  [7.43566425]
#  [2.67372817]
#  [2.84476787]
#  [1.81174767]
#  [1.58524615]
#  [4.36893833]
#  [1.58023687]
#  [8.10120362]
#  [1.91180504]
#  [3.36500824]
#  [2.07919465]
#  [7.20582912]
#  [1.97686028]
#  [2.08330557]
#  [8.78881344]
#  [1.58160067]
#  [2.74215962]
#  [3.01630835]
#  [5.34267776]
#  [1.59089194]
#  [1.57454744]
#  [4.76186497]
#  [2.54718337]
#  [3.1923215 ]
#  [2.85277138]
#  [1.5848403 ]
#  [1.62317855]
#  [2.03725794]
#  [1.59889281]
#  [2.01586875]
#  [1.57742474]
#  [3.09766406]
#  [3.58988034]
#  [3.4306707 ]
#  [2.39699318]
#  [9.02536165]
#  [2.07648494]
#  [2.39692722]
#  [2.75519889]
#  [3.76337873]
#  [5.85015967]
#  [3.14535188]
#  [2.3140023 ]
#  [8.71158943]
#  [2.05297203]
#  [2.22372671]
#  [3.2981568 ]
#  [1.59913852]
#  [2.61965572]
#  [1.59833684]
#  [2.05319465]
#  [4.67114267]
#  [2.88444697]
#  [3.81474179]
#  [1.57641315]
#  [2.34939689]
#  [4.12095107]
#  [1.58356646]
#  [6.64264514]
#  [4.406308  ]
#  [7.95152498]
#  [2.56867373]
#  [4.24341455]
#  [9.35910225]
#  [2.78656248]
#  [1.8607548 ]
#  [3.04553065]
#  [5.47977654]
#  [3.09894671]
#  [2.55445944]
#  [5.71035478]
#  [5.10959567]
#  [1.93693505]
#  [5.798916  ]
#  [3.23811737]
#  [2.43823853]
#  [4.55847926]
#  [2.04174918]
#  [1.82348163]
#  [3.5704583 ]
#  [1.98612579]
#  [1.57774816]
#  [1.57440509]
#  [1.66570472]
#  [4.63178794]
#  [1.84251033]
#  [2.2330218 ]
#  [3.54461519]
#  [2.21525387]
#  [3.21828191]
#  [6.2581319 ]
#  [4.0241126 ]
#  [8.47254673]
#  [6.54927879]
#  [8.56808255]
#  [1.58739665]
#  [2.6170596 ]
#  [1.57423301]
#  [5.29036864]
#  [2.07240894]
#  [3.55714117]
#  [4.479327  ]
#  [2.33489524]
#  [4.59449648]
#  [4.21725027]
#  [7.81901216]
#  [4.38498081]
#  [6.99827806]
#  [2.13422979]
#  [1.65728952]
#  [3.25197617]
#  [1.57476262]
#  [5.90950322]
#  [6.90843797]
#  [4.7538683 ]
#  [4.32147124]
#  [1.58755835]
#  [4.58217951]
#  [7.31790308]
#  [1.58279663]
#  [7.42339083]
#  [3.88701564]
#  [1.62208446]
#  [1.66984133]
#  [1.85395758]
#  [1.62057116]
#  [1.88842626]
#  [3.60181305]
#  [2.30177909]
#  [2.78628744]
#  [8.57964176]
#  [2.87496472]
#  [4.85109348]
#  [2.78263724]
#  [1.64133413]
#  [1.72445757]
#  [3.58017758]
#  [1.83662618]
#  [2.02224801]
#  [2.75048577]
#  [4.33858248]
#  [1.70845614]
#  [1.71984117]
#  [4.89235484]
#  [1.88469199]
#  [4.7000705 ]
#  [1.68442503]
#  [3.21089277]
#  [3.44255588]
#  [4.4117167 ]
#  [2.05242784]
#  [1.67865419]
#  [5.74286831]
#  [2.70503787]
#  [1.78972852]
#  [1.64569594]
#  [4.84820641]
#  [1.61242546]
#  [7.99589293]
#  [7.2731069 ]
#  [3.61004977]
#  [1.94427416]
#  [5.64234605]
#  [2.07669277]
#  [3.06788609]
#  [1.65856761]
#  [7.71219673]
#  [3.02446923]
#  [3.75831882]
#  [5.60090353]
#  [6.85107611]
#  [4.54093048]
#  [1.62469145]
#  [5.14035855]
#  [1.73534418]
#  [4.0723814 ]
#  [2.18650526]
#  [4.46622751]
#  [2.68377502]
#  [5.65573188]
#  [2.63903693]
#  [2.43349574]
#  [5.5935063 ]
#  [1.7610711 ]
#  [4.83061447]
#  [8.52947933]
#  [1.5961567 ]
#  [2.13834083]
#  [1.58257919]
#  [1.57689374]
#  [3.41407624]
#  [2.27075909]
#  [6.48908671]
#  [2.72520224]
#  [8.20105759]
#  [2.63808295]
#  [9.23722077]
#  [2.04425914]
#  [6.45390797]
#  [1.61990491]
#  [3.55851962]
#  [6.68724222]
#  [1.72497758]
#  [2.48771048]
#  [2.76672595]
#  [3.96304464]
#  [7.87398535]
#  [2.77872533]
#  [1.61309784]
#  [3.29302973]
#  [1.60754844]
#  [2.31012331]
#  [3.29244844]
#  [3.46613177]
#  [1.90302255]
#  [3.29188031]
#  [1.92794582]
#  [4.8172126 ]
#  [1.91038245]
#  [8.55139718]
#  [1.66380992]
#  [4.3127199 ]
#  [1.92704669]
#  [6.3129345 ]
#  [1.89979244]
#  [2.00537038]
#  [1.64699459]
#  [1.6077911 ]
#  [4.69695866]
#  [3.76708166]
#  [5.57211566]
#  [1.57665714]
#  [1.83069572]
#  [3.84084642]
#  [8.21093771]
#  [5.62507285]
#  [2.05013179]
#  [3.59672947]
#  [6.19237535]
#  [4.01812351]
#  [2.75422936]
#  [1.60881408]
#  [3.29494293]
#  [7.4112026 ]
#  [1.76337449]
#  [6.4692649 ]
#  [1.72159739]
#  [8.7448415 ]
#  [1.78529532]
#  [2.97390437]
#  [2.01746655]
#  [1.87668724]
#  [1.5743295 ]
#  [4.4104732 ]
#  [3.37136272]
#  [2.96237893]
#  [3.92644469]
#  [2.52548572]
#  [1.69401774]
#  [2.03578694]
#  [1.84227228]
#  [2.35827501]
#  [2.90170093]
#  [1.79232992]
#  [7.13918169]
#  [3.48618224]
#  [3.69287988]
#  [5.61005331]
#  [5.39306597]
#  [8.82386413]
#  [2.47653644]
#  [2.26142362]
#  [5.53307957]
#  [2.33031311]
#  [2.94486681]
#  [1.87820083]
#  [2.88252901]
#  [2.87525632]
#  [1.65302246]
#  [2.53252359]
#  [2.5919919 ]
#  [2.23823422]
#  [2.79129577]
#  [8.20179152]
#  [1.82138271]
#  [5.39609044]
#  [1.75674315]
#  [8.3595464 ]
#  [2.27132935]
#  [1.62839817]
#  [1.7329674 ]
#  [7.31750762]
#  [4.66656566]
#  [2.20737305]
#  [1.81104909]
#  [5.44896026]
#  [1.62429029]
#  [8.03460203]
#  [3.35107425]
#  [2.19155802]
#  [1.65543216]
#  [2.61950047]
#  [2.34470735]
#  [2.29922938]
#  [2.5489052 ]
#  [1.60801195]
#  [2.08103209]
#  [1.92154551]
#  [8.52572751]
#  [6.65784272]
#  [8.5708659 ]
#  [7.7840912 ]
#  [5.90840849]
#  [1.65191204]
#  [1.67221901]
#  [1.89193682]
#  [2.39263731]
#  [1.57422351]
#  [1.60021453]
#  [2.95675352]
#  [6.97481774]
#  [3.93181884]
#  [1.64641982]
#  [3.61771474]
#  [2.75955288]
#  [1.62811345]
#  [2.97344815]
#  [2.54149147]
#  [3.71999692]
#  [1.71611865]
#  [2.4172153 ]
#  [2.18189446]
#  [6.61858672]
#  [2.63006927]
#  [7.08533839]
#  [2.4847701 ]
#  [1.6000451 ]
#  [1.68635571]
#  [1.96344631]
#  [3.02402975]
#  [3.10063362]
#  [1.63391925]
#  [1.57434604]
#  [7.6318153 ]
#  [9.01601118]
#  [6.99441439]
#  [2.20896335]
#  [6.93607709]
#  [2.27436209]
#  [1.99841266]
#  [2.30367631]
#  [3.37558823]
#  [1.8133752 ]
#  [2.03343822]
#  [2.51767307]
#  [1.63294931]
#  [3.3056691 ]
#  [7.28028608]
#  [2.22171161]
#  [2.03034154]
#  [3.26965602]
#  [8.56534041]
#  [7.55324887]
#  [7.76878543]
#  [5.55144662]
#  [2.59757623]
#  [2.1618498 ]
#  [2.73447272]
#  [2.12691907]
#  [2.54373184]
#  [2.79785895]
#  [7.20104246]
#  [1.58579366]
#  [2.06045139]
#  [1.85319703]
#  [3.95797633]
#  [2.53385519]
#  [1.80540024]
#  [8.66949836]
#  [1.73724838]
#  [3.1911139 ]
#  [1.66249981]
#  [2.46938599]
#  [1.90685182]
#  [3.07077753]
#  [8.99414841]
#  [1.58591407]
#  [9.35823997]
#  [2.04649289]
#  [1.71689254]
#  [3.55766842]
#  [5.93077351]
#  [2.98396925]
#  [9.04668831]
#  [1.89990919]
#  [5.07746365]
#  [1.5746599 ]
#  [3.48001145]
#  [1.75438747]
#  [8.12106565]
#  [2.18621204]
#  [3.33121418]
#  [8.47224294]
#  [3.59420972]
#  [3.09492838]
#  [1.61758467]
#  [2.69789291]
#  [2.65742464]
#  [1.60680306]
#  [3.22624916]
#  [8.71292599]
#  [2.39624051]
#  [6.32541909]
#  [6.69395509]
#  [2.1423826 ]
#  [2.11128084]
#  [7.61794176]
#  [1.66479477]
#  [9.30085998]
#  [1.74934056]
#  [1.6592307 ]
#  [1.71041761]
#  [1.96258224]
#  [1.68551262]
#  [1.86880587]
#  [8.4911248 ]
#  [3.44367291]
#  [3.24794064]
#  [7.43769126]
#  [5.27419444]
#  [2.50167709]
#  [2.55247903]
#  [3.24853372]
#  [3.45783514]
#  [1.6095199 ]
#  [1.89356844]
#  [1.62409405]
#  [1.63743985]
#  [7.38031193]
#  [9.15859973]
#  [2.23812791]
#  [2.14093621]
#  [1.64898797]
#  [1.5955298 ]
#  [3.10466528]
#  [2.01650089]
#  [6.42664883]
#  [2.83837884]
#  [6.71295506]
#  [1.6091694 ]
#  [2.99597363]
#  [1.8179551 ]
#  [1.57916273]
#  [3.15975409]
#  [5.58198378]
#  [1.57868974]
#  [6.10393279]
#  [6.5478393 ]
#  [1.61048904]
#  [8.11375116]
#  [2.13773102]
#  [1.65874959]
#  [6.06719853]
#  [1.5941734 ]
#  [1.6006447 ]
#  [1.81081373]
#  [2.94726763]
#  [6.95824286]
#  [4.20600022]
#  [6.21091072]
#  [1.83685977]
#  [2.49517958]
#  [2.21865512]
#  [6.35885276]
#  [6.80332189]
#  [2.15651541]
#  [6.59212406]
#  [7.0372662 ]
#  [2.33783581]
#  [2.49378071]
#  [1.61298845]
#  [5.58246192]
#  [2.87536317]
#  [2.46473643]
#  [2.57483252]
#  [6.2160547 ]
#  [5.11099783]
#  [2.65648973]
#  [8.3207852 ]
#  [8.79825756]
#  [2.03642964]
#  [2.83609461]
#  [1.83916106]
#  [1.85863198]
#  [1.97307966]
#  [2.0773117 ]
#  [3.11589074]
#  [1.77853633]
#  [3.79280901]
#  [2.01972691]
#  [4.2343131 ]
#  [2.10640742]
#  [7.52061846]
#  [1.6629086 ]
#  [1.88974059]
#  [3.81113692]
#  [6.14414115]
#  [2.99011803]
#  [1.57650041]
#  [4.9780361 ]
#  [5.91965985]
#  [1.65027586]
#  [2.04370155]
#  [1.67763032]
#  [5.09917394]
#  [3.7267907 ]
#  [1.57834827]
#  [3.64365358]
#  [7.91200168]
#  [6.03767282]
#  [2.04842551]
#  [2.33837353]
#  [4.8525408 ]
#  [3.76468207]
#  [2.00418341]
#  [5.813792  ]
#  [1.62325698]
#  [1.71270285]
#  [1.63390895]
#  [8.28646908]
#  [1.57435678]
#  [2.47693325]
#  [5.02105005]
#  [2.67811362]
#  [6.3728289 ]
#  [3.59396578]
#  [2.07642339]
#  [1.90981276]
#  [5.25635465]
#  [6.47027309]
#  [1.58169963]
#  [7.26639763]
#  [2.00622345]
#  [2.30442253]
#  [8.26853538]
#  [1.91639007]
#  [1.58532667]
#  [7.44852549]
#  [1.61795259]
#  [2.55817302]
#  [3.3267377 ]
#  [1.86819331]
#  [5.10696876]
#  [3.59979686]
#  [5.66167447]
#  [2.07724179]
#  [1.69947297]
#  [2.69409615]
#  [5.26193912]
#  [2.37699463]
#  [1.61125399]
#  [1.57422255]
#  [1.95587313]
#  [8.19906212]
#  [1.63326286]
#  [7.73157716]
#  [2.74692786]
#  [2.92466925]
#  [1.59457249]
#  [2.68550665]
#  [2.28264654]
#  [1.75928749]
#  [8.42415045]
#  [3.2059653 ]
#  [2.54303243]
#  [8.70286546]
#  [1.60047462]
#  [2.92824653]
#  [1.60030981]
#  [7.40650589]
#  [3.08742151]
#  [1.61068454]
#  [2.47978904]
#  [1.57885078]
#  [2.4932827 ]
#  [5.44193138]
#  [1.79161885]
#  [2.01407012]
#  [6.59046347]
#  [2.88742029]
#  [3.18546315]
#  [1.89071814]
#  [5.57082155]
#  [6.39737097]
#  [2.15582911]
#  [1.78961728]
#  [2.85097094]
#  [2.84630536]
#  [3.92775542]
#  [1.92987034]
#  [4.41235253]
#  [2.68244666]
#  [3.24177081]
#  [3.22283166]
#  [1.66924555]
#  [1.61118574]
#  [1.67107194]
#  [2.91981961]
#  [4.43335813]
#  [3.80821589]
#  [3.57372826]
#  [1.99786192]
#  [1.58999523]
#  [2.0904656 ]
#  [2.09029614]
#  [9.33712504]
#  [3.59594828]
#  [2.05550337]
#  [1.82922622]
#  [1.8310111 ]
#  [6.17557984]
#  [2.72400531]
#  [1.57962257]
#  [2.27044333]
#  [1.59539391]
#  [1.66195208]
#  [2.66960263]
#  [3.63845924]
#  [3.28604298]
#  [6.0068144 ]
#  [3.22909053]
#  [2.62857927]
#  [3.16085115]
#  [2.65515201]
#  [1.58565656]
#  [5.11606543]
#  [1.61502783]
#  [2.07326064]
#  [2.00760903]
#  [2.26619532]
#  [1.5768841 ]
#  [3.17105357]
#  [3.58751552]
#  [2.16039754]
#  [5.71284007]
#  [2.3958165 ]
#  [1.65783598]
#  [2.13252404]
#  [8.4562643 ]
#  [1.80180137]
#  [1.88798127]
#  [3.25639593]
#  [3.82640678]
#  [6.44552305]
#  [6.76604443]
#  [2.70370628]
#  [3.48053924]
#  [2.498187  ]
#  [1.61048744]
#  [2.79618417]
#  [7.07371835]
#  [1.91709288]
#  [3.11614594]
#  [3.05291716]
#  [2.06282597]
#  [2.53633766]
#  [2.39812301]
#  [2.55744481]
#  [9.37819768]
#  [2.19333156]
#  [2.23884226]
#  [1.5960282 ]
#  [2.55810636]
#  [1.57802668]
#  [6.3379125 ]
#  [4.62199566]
#  [3.2833521 ]
#  [1.58202459]
#  [3.98297245]
#  [3.51980738]
#  [1.96534115]
#  [1.6607307 ]
#  [2.12994547]
#  [2.17968701]
#  [4.56547803]
#  [1.85397524]
#  [2.67304737]
#  [2.2345193 ]
#  [2.96287232]
#  [3.60425988]
#  [2.16617581]
#  [1.7748026 ]
#  [1.9796665 ]
#  [8.78352209]
#  [4.24349239]
#  [2.26626516]
#  [2.37297811]
#  [2.24603046]
#  [2.88883825]
#  [8.11347178]
#  [6.93815989]
#  [8.15630591]
#  [2.73546995]
#  [1.5796023 ]
#  [8.40676518]
#  [1.79490815]
#  [1.69907454]
#  [3.83404238]
#  [2.3767882 ]
#  [3.76554615]
#  [1.85349119]
#  [4.80268857]
#  [8.55616411]
#  [6.00328437]
#  [1.62210814]
#  [4.17307751]
#  [3.0765278 ]
#  [2.97314536]
#  [1.86010104]
#  [6.15077861]
#  [8.69680987]
#  [3.33681323]
#  [6.26456194]
#  [2.26919961]
#  [1.59952791]
#  [1.91307779]
#  [3.51977148]
#  [2.37449116]
#  [1.70765123]
#  [2.16113836]
#  [6.80823524]
#  [2.11925898]
#  [3.46551494]
#  [1.91850309]
#  [1.62350236]
#  [1.62774248]
#  [3.31396289]
#  [4.01179996]
#  [1.64001492]
#  [3.16800526]
#  [4.62470047]
#  [1.98907597]
#  [2.59953187]
#  [5.08099067]
#  [1.57432323]
#  [3.92411246]
#  [6.8883433 ]
#  [4.40466189]
#  [6.73684006]
#  [1.5743241 ]
#  [2.82628302]
#  [2.85614856]
#  [6.07958298]
#  [2.06910619]
#  [8.17209094]
#  [3.4228828 ]
#  [9.33918713]
#  [3.40851857]
#  [1.67652064]
#  [2.47661053]
#  [8.85842314]
#  [4.06503257]
#  [3.90904752]
#  [1.92859674]
#  [1.91771456]
#  [4.62828568]
#  [3.19403419]
#  [4.14324408]
#  [1.78604338]
#  [1.86400942]
#  [1.63432658]
#  [2.89792796]
#  [1.88404221]
#  [2.48268708]
#  [2.45159288]
#  [3.95470465]
#  [1.6391616 ]
#  [6.06824225]
#  [1.65400483]
#  [3.09200502]
#  [2.23778643]
#  [5.61648539]
#  [5.74317865]
#  [8.37641921]
#  [2.96965734]
#  [1.57498426]
#  [7.18926732]
#  [7.09517024]
#  [4.539278  ]
#  [1.92638955]
#  [1.58409442]
#  [3.00913562]
#  [1.75357985]
#  [7.54867265]
#  [3.18778683]
#  [3.11382052]
#  [3.03950227]
#  [3.05623933]
#  [8.61553009]
#  [3.55254272]
#  [2.44739026]
#  [3.0369399 ]
#  [3.06644933]
#  [9.35205676]
#  [3.36540735]
#  [3.48678591]
#  [2.49106972]
#  [4.73424155]
#  [2.26617127]
#  [1.80618349]
#  [3.53291981]
#  [5.69251657]
#  [1.67614899]
#  [3.32388916]
#  [3.0195987 ]
#  [2.51407768]
#  [3.85388369]
#  [9.45057423]
#  [5.21176035]
#  [8.96405601]
#  [2.14020723]
#  [7.21844131]
#  [2.52103869]
#  [1.77878131]
#  [2.2901142 ]
#  [7.43658504]
#  [2.47810143]
#  [5.29261389]
#  [2.14545606]
#  [2.61511704]
#  [9.42425156]
#  [2.26832164]
#  [8.06029475]
#  [5.77278817]
#  [2.90857141]
#  [8.30671611]
#  [5.07291417]
#  [2.33913727]
#  [1.59077089]
#  [2.28432945]
#  [1.72994549]
#  [4.7771736 ]
#  [6.8768482 ]
#  [7.58098648]
#  [1.61263537]
#  [2.08740578]
#  [3.95860275]
#  [6.92806279]
#  [2.78802815]
#  [2.87564675]
#  [2.48683993]
#  [1.60560259]
#  [7.07585182]
#  [1.67898711]
#  [1.59489739]
#  [7.30819256]
#  [2.76894361]
#  [3.62590009]
#  [1.68213479]
#  [2.27286855]
#  [4.87551178]
#  [3.3488229 ]
#  [4.16337388]
#  [3.96653272]
#  [3.21189149]
#  [2.35974203]
#  [2.54457731]
#  [2.57350868]
#  [7.17132591]
#  [1.98569264]
#  [1.76045586]
#  [2.46046175]
#  [1.61578989]
#  [2.3471179 ]
#  [2.8008491 ]
#  [2.14547013]
#  [1.7375144 ]
#  [2.21874644]
#  [1.82050227]
#  [4.47569887]
#  [1.63926937]
#  [1.595508  ]
#  [1.58963143]
#  [1.65892533]
#  [1.64842851]
#  [1.60896658]
#  [2.17455667]
#  [9.43653706]
#  [1.60045649]
#  [2.53248451]
#  [1.6689362 ]
#  [3.46349383]
#  [1.76078027]
#  [2.76060992]
#  [1.94735979]
#  [2.57755529]
#  [6.22426362]
#  [4.10050786]
#  [1.57764822]
#  [3.69958101]
#  [8.77742244]
#  [3.22207324]
#  [2.74793348]
#  [4.83952892]
#  [9.09079059]
#  [6.34573944]
#  [8.50942093]
#  [5.64709163]
#  [1.60882606]
#  [1.58274443]
#  [1.60982271]
#  [8.87901325]
#  [8.39123927]
#  [8.48256705]
#  [2.88469271]
#  [1.86405463]
#  [1.6054788 ]
#  [3.21395932]
#  [3.56410715]
#  [2.34690943]
#  [3.02099377]
#  [7.31178979]
#  [8.66793191]
#  [1.71737975]
#  [2.32329157]
#  [3.14761804]
#  [2.38298233]
#  [2.37743333]
#  [2.52460315]
#  [7.97099218]
#  [5.84766451]
#  [2.96991115]
#  [1.72350285]
#  [3.4105944 ]
#  [2.53923753]
#  [6.04445766]
#  [2.65148176]
#  [6.76522329]]

# %%
X_poly.dot(lin_reg.coef_.T)+lin_reg.intercept_
# Out:
# array([[1.79615044],
#        [4.13246995],
#        [2.55917163],
#        [9.46865159],
#        [2.57781383],
#        [1.74584036],
#        [8.38854112],
#        [4.71547317],
#        [3.07712933],
#        [6.19499735],
#        [2.08809549],
#        [2.11732598],
#        [1.59230333],
#        [1.83811399],
#        [5.42674919],
#        [1.58370966],
#        [5.88498674],
#        [2.63800717],
#        [4.13231041],
#        [1.90284687],
#        [2.05297611],
#        [1.6055706 ],
#        [1.7959617 ],
#        [2.76235919],
#        [1.90621622],
#        [1.89307059],
#        [1.96707173],
#        [6.16519448],
#        [3.09562368],
#        [3.52727839],
#        [1.57446704],
#        [5.44715791],
#        [6.72437532],
#        [5.30740788],
#        [3.16499068],
#        [2.25904384],
#        [1.57630113],
#        [2.68799802],
#        [3.5590106 ],
#        [1.76712721],
#        [6.66701149],
#        [1.59572663],
#        [2.20745446],
#        [3.29653441],
#        [8.37651477],
#        [4.80325915],
#        [1.65272644],
#        [1.60725928],
#        [4.17726123],
#        [3.04355125],
#        [2.56460243],
#        [5.53572839],
#        [8.66010371],
#        [6.26506412],
#        [2.77975129],
#        [3.34130158],
#        [4.75393866],
#        [2.0819143 ],
#        [1.57514455],
#        [2.04294423],
#        [2.50030091],
#        [6.83726214],
#        [7.43566425],
#        [2.67372817],
#        [2.84476787],
#        [1.81174767],
#        [1.58524615],
#        [4.36893833],
#        [1.58023687],
#        [8.10120362],
#        [1.91180504],
#        [3.36500824],
#        [2.07919465],
#        [7.20582912],
#        [1.97686028],
#        [2.08330557],
#        [8.78881344],
#        [1.58160067],
#        [2.74215962],
#        [3.01630835],
#        [5.34267776],
#        [1.59089194],
#        [1.57454744],
#        [4.76186497],
#        [2.54718337],
#        [3.1923215 ],
#        [2.85277138],
#        [1.5848403 ],
#        [1.62317855],
#        [2.03725794],
#        [1.59889281],
#        [2.01586875],
#        [1.57742474],
#        [3.09766406],
#        [3.58988034],
#        [3.4306707 ],
#        [2.39699318],
#        [9.02536165],
#        [2.07648494],
#        [2.39692722],
#        [2.75519889],
#        [3.76337873],
#        [5.85015967],
#        [3.14535188],
#        [2.3140023 ],
#        [8.71158943],
#        [2.05297203],
#        [2.22372671],
#        [3.2981568 ],
#        [1.59913852],
#        [2.61965572],
#        [1.59833684],
#        [2.05319465],
#        [4.67114267],
#        [2.88444697],
#        [3.81474179],
#        [1.57641315],
#        [2.34939689],
#        [4.12095107],
#        [1.58356646],
#        [6.64264514],
#        [4.406308  ],
#        [7.95152498],
#        [2.56867373],
#        [4.24341455],
#        [9.35910225],
#        [2.78656248],
#        [1.8607548 ],
#        [3.04553065],
#        [5.47977654],
#        [3.09894671],
#        [2.55445944],
#        [5.71035478],
#        [5.10959567],
#        [1.93693505],
#        [5.798916  ],
#        [3.23811737],
#        [2.43823853],
#        [4.55847926],
#        [2.04174918],
#        [1.82348163],
#        [3.5704583 ],
#        [1.98612579],
#        [1.57774816],
#        [1.57440509],
#        [1.66570472],
#        [4.63178794],
#        [1.84251033],
#        [2.2330218 ],
#        [3.54461519],
#        [2.21525387],
#        [3.21828191],
#        [6.2581319 ],
#        [4.0241126 ],
#        [8.47254673],
#        [6.54927879],
#        [8.56808255],
#        [1.58739665],
#        [2.6170596 ],
#        [1.57423301],
#        [5.29036864],
#        [2.07240894],
#        [3.55714117],
#        [4.479327  ],
#        [2.33489524],
#        [4.59449648],
#        [4.21725027],
#        [7.81901216],
#        [4.38498081],
#        [6.99827806],
#        [2.13422979],
#        [1.65728952],
#        [3.25197617],
#        [1.57476262],
#        [5.90950322],
#        [6.90843797],
#        [4.7538683 ],
#        [4.32147124],
#        [1.58755835],
#        [4.58217951],
#        [7.31790308],
#        [1.58279663],
#        [7.42339083],
#        [3.88701564],
#        [1.62208446],
#        [1.66984133],
#        [1.85395758],
#        [1.62057116],
#        [1.88842626],
#        [3.60181305],
#        [2.30177909],
#        [2.78628744],
#        [8.57964176],
#        [2.87496472],
#        [4.85109348],
#        [2.78263724],
#        [1.64133413],
#        [1.72445757],
#        [3.58017758],
#        [1.83662618],
#        [2.02224801],
#        [2.75048577],
#        [4.33858248],
#        [1.70845614],
#        [1.71984117],
#        [4.89235484],
#        [1.88469199],
#        [4.7000705 ],
#        [1.68442503],
#        [3.21089277],
#        [3.44255588],
#        [4.4117167 ],
#        [2.05242784],
#        [1.67865419],
#        [5.74286831],
#        [2.70503787],
#        [1.78972852],
#        [1.64569594],
#        [4.84820641],
#        [1.61242546],
#        [7.99589293],
#        [7.2731069 ],
#        [3.61004977],
#        [1.94427416],
#        [5.64234605],
#        [2.07669277],
#        [3.06788609],
#        [1.65856761],
#        [7.71219673],
#        [3.02446923],
#        [3.75831882],
#        [5.60090353],
#        [6.85107611],
#        [4.54093048],
#        [1.62469145],
#        [5.14035855],
#        [1.73534418],
#        [4.0723814 ],
#        [2.18650526],
#        [4.46622751],
#        [2.68377502],
#        [5.65573188],
#        [2.63903693],
#        [2.43349574],
#        [5.5935063 ],
#        [1.7610711 ],
#        [4.83061447],
#        [8.52947933],
#        [1.5961567 ],
#        [2.13834083],
#        [1.58257919],
#        [1.57689374],
#        [3.41407624],
#        [2.27075909],
#        [6.48908671],
#        [2.72520224],
#        [8.20105759],
#        [2.63808295],
#        [9.23722077],
#        [2.04425914],
#        [6.45390797],
#        [1.61990491],
#        [3.55851962],
#        [6.68724222],
#        [1.72497758],
#        [2.48771048],
#        [2.76672595],
#        [3.96304464],
#        [7.87398535],
#        [2.77872533],
#        [1.61309784],
#        [3.29302973],
#        [1.60754844],
#        [2.31012331],
#        [3.29244844],
#        [3.46613177],
#        [1.90302255],
#        [3.29188031],
#        [1.92794582],
#        [4.8172126 ],
#        [1.91038245],
#        [8.55139718],
#        [1.66380992],
#        [4.3127199 ],
#        [1.92704669],
#        [6.3129345 ],
#        [1.89979244],
#        [2.00537038],
#        [1.64699459],
#        [1.6077911 ],
#        [4.69695866],
#        [3.76708166],
#        [5.57211566],
#        [1.57665714],
#        [1.83069572],
#        [3.84084642],
#        [8.21093771],
#        [5.62507285],
#        [2.05013179],
#        [3.59672947],
#        [6.19237535],
#        [4.01812351],
#        [2.75422936],
#        [1.60881408],
#        [3.29494293],
#        [7.4112026 ],
#        [1.76337449],
#        [6.4692649 ],
#        [1.72159739],
#        [8.7448415 ],
#        [1.78529532],
#        [2.97390437],
#        [2.01746655],
#        [1.87668724],
#        [1.5743295 ],
#        [4.4104732 ],
#        [3.37136272],
#        [2.96237893],
#        [3.92644469],
#        [2.52548572],
#        [1.69401774],
#        [2.03578694],
#        [1.84227228],
#        [2.35827501],
#        [2.90170093],
#        [1.79232992],
#        [7.13918169],
#        [3.48618224],
#        [3.69287988],
#        [5.61005331],
#        [5.39306597],
#        [8.82386413],
#        [2.47653644],
#        [2.26142362],
#        [5.53307957],
#        [2.33031311],
#        [2.94486681],
#        [1.87820083],
#        [2.88252901],
#        [2.87525632],
#        [1.65302246],
#        [2.53252359],
#        [2.5919919 ],
#        [2.23823422],
#        [2.79129577],
#        [8.20179152],
#        [1.82138271],
#        [5.39609044],
#        [1.75674315],
#        [8.3595464 ],
#        [2.27132935],
#        [1.62839817],
#        [1.7329674 ],
#        [7.31750762],
#        [4.66656566],
#        [2.20737305],
#        [1.81104909],
#        [5.44896026],
#        [1.62429029],
#        [8.03460203],
#        [3.35107425],
#        [2.19155802],
#        [1.65543216],
#        [2.61950047],
#        [2.34470735],
#        [2.29922938],
#        [2.5489052 ],
#        [1.60801195],
#        [2.08103209],
#        [1.92154551],
#        [8.52572751],
#        [6.65784272],
#        [8.5708659 ],
#        [7.7840912 ],
#        [5.90840849],
#        [1.65191204],
#        [1.67221901],
#        [1.89193682],
#        [2.39263731],
#        [1.57422351],
#        [1.60021453],
#        [2.95675352],
#        [6.97481774],
#        [3.93181884],
#        [1.64641982],
#        [3.61771474],
#        [2.75955288],
#        [1.62811345],
#        [2.97344815],
#        [2.54149147],
#        [3.71999692],
#        [1.71611865],
#        [2.4172153 ],
#        [2.18189446],
#        [6.61858672],
#        [2.63006927],
#        [7.08533839],
#        [2.4847701 ],
#        [1.6000451 ],
#        [1.68635571],
#        [1.96344631],
#        [3.02402975],
#        [3.10063362],
#        [1.63391925],
#        [1.57434604],
#        [7.6318153 ],
#        [9.01601118],
#        [6.99441439],
#        [2.20896335],
#        [6.93607709],
#        [2.27436209],
#        [1.99841266],
#        [2.30367631],
#        [3.37558823],
#        [1.8133752 ],
#        [2.03343822],
#        [2.51767307],
#        [1.63294931],
#        [3.3056691 ],
#        [7.28028608],
#        [2.22171161],
#        [2.03034154],
#        [3.26965602],
#        [8.56534041],
#        [7.55324887],
#        [7.76878543],
#        [5.55144662],
#        [2.59757623],
#        [2.1618498 ],
#        [2.73447272],
#        [2.12691907],
#        [2.54373184],
#        [2.79785895],
#        [7.20104246],
#        [1.58579366],
#        [2.06045139],
#        [1.85319703],
#        [3.95797633],
#        [2.53385519],
#        [1.80540024],
#        [8.66949836],
#        [1.73724838],
#        [3.1911139 ],
#        [1.66249981],
#        [2.46938599],
#        [1.90685182],
#        [3.07077753],
#        [8.99414841],
#        [1.58591407],
#        [9.35823997],
#        [2.04649289],
#        [1.71689254],
#        [3.55766842],
#        [5.93077351],
#        [2.98396925],
#        [9.04668831],
#        [1.89990919],
#        [5.07746365],
#        [1.5746599 ],
#        [3.48001145],
#        [1.75438747],
#        [8.12106565],
#        [2.18621204],
#        [3.33121418],
#        [8.47224294],
#        [3.59420972],
#        [3.09492838],
#        [1.61758467],
#        [2.69789291],
#        [2.65742464],
#        [1.60680306],
#        [3.22624916],
#        [8.71292599],
#        [2.39624051],
#        [6.32541909],
#        [6.69395509],
#        [2.1423826 ],
#        [2.11128084],
#        [7.61794176],
#        [1.66479477],
#        [9.30085998],
#        [1.74934056],
#        [1.6592307 ],
#        [1.71041761],
#        [1.96258224],
#        [1.68551262],
#        [1.86880587],
#        [8.4911248 ],
#        [3.44367291],
#        [3.24794064],
#        [7.43769126],
#        [5.27419444],
#        [2.50167709],
#        [2.55247903],
#        [3.24853372],
#        [3.45783514],
#        [1.6095199 ],
#        [1.89356844],
#        [1.62409405],
#        [1.63743985],
#        [7.38031193],
#        [9.15859973],
#        [2.23812791],
#        [2.14093621],
#        [1.64898797],
#        [1.5955298 ],
#        [3.10466528],
#        [2.01650089],
#        [6.42664883],
#        [2.83837884],
#        [6.71295506],
#        [1.6091694 ],
#        [2.99597363],
#        [1.8179551 ],
#        [1.57916273],
#        [3.15975409],
#        [5.58198378],
#        [1.57868974],
#        [6.10393279],
#        [6.5478393 ],
#        [1.61048904],
#        [8.11375116],
#        [2.13773102],
#        [1.65874959],
#        [6.06719853],
#        [1.5941734 ],
#        [1.6006447 ],
#        [1.81081373],
#        [2.94726763],
#        [6.95824286],
#        [4.20600022],
#        [6.21091072],
#        [1.83685977],
#        [2.49517958],
#        [2.21865512],
#        [6.35885276],
#        [6.80332189],
#        [2.15651541],
#        [6.59212406],
#        [7.0372662 ],
#        [2.33783581],
#        [2.49378071],
#        [1.61298845],
#        [5.58246192],
#        [2.87536317],
#        [2.46473643],
#        [2.57483252],
#        [6.2160547 ],
#        [5.11099783],
#        [2.65648973],
#        [8.3207852 ],
#        [8.79825756],
#        [2.03642964],
#        [2.83609461],
#        [1.83916106],
#        [1.85863198],
#        [1.97307966],
#        [2.0773117 ],
#        [3.11589074],
#        [1.77853633],
#        [3.79280901],
#        [2.01972691],
#        [4.2343131 ],
#        [2.10640742],
#        [7.52061846],
#        [1.6629086 ],
#        [1.88974059],
#        [3.81113692],
#        [6.14414115],
#        [2.99011803],
#        [1.57650041],
#        [4.9780361 ],
#        [5.91965985],
#        [1.65027586],
#        [2.04370155],
#        [1.67763032],
#        [5.09917394],
#        [3.7267907 ],
#        [1.57834827],
#        [3.64365358],
#        [7.91200168],
#        [6.03767282],
#        [2.04842551],
#        [2.33837353],
#        [4.8525408 ],
#        [3.76468207],
#        [2.00418341],
#        [5.813792  ],
#        [1.62325698],
#        [1.71270285],
#        [1.63390895],
#        [8.28646908],
#        [1.57435678],
#        [2.47693325],
#        [5.02105005],
#        [2.67811362],
#        [6.3728289 ],
#        [3.59396578],
#        [2.07642339],
#        [1.90981276],
#        [5.25635465],
#        [6.47027309],
#        [1.58169963],
#        [7.26639763],
#        [2.00622345],
#        [2.30442253],
#        [8.26853538],
#        [1.91639007],
#        [1.58532667],
#        [7.44852549],
#        [1.61795259],
#        [2.55817302],
#        [3.3267377 ],
#        [1.86819331],
#        [5.10696876],
#        [3.59979686],
#        [5.66167447],
#        [2.07724179],
#        [1.69947297],
#        [2.69409615],
#        [5.26193912],
#        [2.37699463],
#        [1.61125399],
#        [1.57422255],
#        [1.95587313],
#        [8.19906212],
#        [1.63326286],
#        [7.73157716],
#        [2.74692786],
#        [2.92466925],
#        [1.59457249],
#        [2.68550665],
#        [2.28264654],
#        [1.75928749],
#        [8.42415045],
#        [3.2059653 ],
#        [2.54303243],
#        [8.70286546],
#        [1.60047462],
#        [2.92824653],
#        [1.60030981],
#        [7.40650589],
#        [3.08742151],
#        [1.61068454],
#        [2.47978904],
#        [1.57885078],
#        [2.4932827 ],
#        [5.44193138],
#        [1.79161885],
#        [2.01407012],
#        [6.59046347],
#        [2.88742029],
#        [3.18546315],
#        [1.89071814],
#        [5.57082155],
#        [6.39737097],
#        [2.15582911],
#        [1.78961728],
#        [2.85097094],
#        [2.84630536],
#        [3.92775542],
#        [1.92987034],
#        [4.41235253],
#        [2.68244666],
#        [3.24177081],
#        [3.22283166],
#        [1.66924555],
#        [1.61118574],
#        [1.67107194],
#        [2.91981961],
#        [4.43335813],
#        [3.80821589],
#        [3.57372826],
#        [1.99786192],
#        [1.58999523],
#        [2.0904656 ],
#        [2.09029614],
#        [9.33712504],
#        [3.59594828],
#        [2.05550337],
#        [1.82922622],
#        [1.8310111 ],
#        [6.17557984],
#        [2.72400531],
#        [1.57962257],
#        [2.27044333],
#        [1.59539391],
#        [1.66195208],
#        [2.66960263],
#        [3.63845924],
#        [3.28604298],
#        [6.0068144 ],
#        [3.22909053],
#        [2.62857927],
#        [3.16085115],
#        [2.65515201],
#        [1.58565656],
#        [5.11606543],
#        [1.61502783],
#        [2.07326064],
#        [2.00760903],
#        [2.26619532],
#        [1.5768841 ],
#        [3.17105357],
#        [3.58751552],
#        [2.16039754],
#        [5.71284007],
#        [2.3958165 ],
#        [1.65783598],
#        [2.13252404],
#        [8.4562643 ],
#        [1.80180137],
#        [1.88798127],
#        [3.25639593],
#        [3.82640678],
#        [6.44552305],
#        [6.76604443],
#        [2.70370628],
#        [3.48053924],
#        [2.498187  ],
#        [1.61048744],
#        [2.79618417],
#        [7.07371835],
#        [1.91709288],
#        [3.11614594],
#        [3.05291716],
#        [2.06282597],
#        [2.53633766],
#        [2.39812301],
#        [2.55744481],
#        [9.37819768],
#        [2.19333156],
#        [2.23884226],
#        [1.5960282 ],
#        [2.55810636],
#        [1.57802668],
#        [6.3379125 ],
#        [4.62199566],
#        [3.2833521 ],
#        [1.58202459],
#        [3.98297245],
#        [3.51980738],
#        [1.96534115],
#        [1.6607307 ],
#        [2.12994547],
#        [2.17968701],
#        [4.56547803],
#        [1.85397524],
#        [2.67304737],
#        [2.2345193 ],
#        [2.96287232],
#        [3.60425988],
#        [2.16617581],
#        [1.7748026 ],
#        [1.9796665 ],
#        [8.78352209],
#        [4.24349239],
#        [2.26626516],
#        [2.37297811],
#        [2.24603046],
#        [2.88883825],
#        [8.11347178],
#        [6.93815989],
#        [8.15630591],
#        [2.73546995],
#        [1.5796023 ],
#        [8.40676518],
#        [1.79490815],
#        [1.69907454],
#        [3.83404238],
#        [2.3767882 ],
#        [3.76554615],
#        [1.85349119],
#        [4.80268857],
#        [8.55616411],
#        [6.00328437],
#        [1.62210814],
#        [4.17307751],
#        [3.0765278 ],
#        [2.97314536],
#        [1.86010104],
#        [6.15077861],
#        [8.69680987],
#        [3.33681323],
#        [6.26456194],
#        [2.26919961],
#        [1.59952791],
#        [1.91307779],
#        [3.51977148],
#        [2.37449116],
#        [1.70765123],
#        [2.16113836],
#        [6.80823524],
#        [2.11925898],
#        [3.46551494],
#        [1.91850309],
#        [1.62350236],
#        [1.62774248],
#        [3.31396289],
#        [4.01179996],
#        [1.64001492],
#        [3.16800526],
#        [4.62470047],
#        [1.98907597],
#        [2.59953187],
#        [5.08099067],
#        [1.57432323],
#        [3.92411246],
#        [6.8883433 ],
#        [4.40466189],
#        [6.73684006],
#        [1.5743241 ],
#        [2.82628302],
#        [2.85614856],
#        [6.07958298],
#        [2.06910619],
#        [8.17209094],
#        [3.4228828 ],
#        [9.33918713],
#        [3.40851857],
#        [1.67652064],
#        [2.47661053],
#        [8.85842314],
#        [4.06503257],
#        [3.90904752],
#        [1.92859674],
#        [1.91771456],
#        [4.62828568],
#        [3.19403419],
#        [4.14324408],
#        [1.78604338],
#        [1.86400942],
#        [1.63432658],
#        [2.89792796],
#        [1.88404221],
#        [2.48268708],
#        [2.45159288],
#        [3.95470465],
#        [1.6391616 ],
#        [6.06824225],
#        [1.65400483],
#        [3.09200502],
#        [2.23778643],
#        [5.61648539],
#        [5.74317865],
#        [8.37641921],
#        [2.96965734],
#        [1.57498426],
#        [7.18926732],
#        [7.09517024],
#        [4.539278  ],
#        [1.92638955],
#        [1.58409442],
#        [3.00913562],
#        [1.75357985],
#        [7.54867265],
#        [3.18778683],
#        [3.11382052],
#        [3.03950227],
#        [3.05623933],
#        [8.61553009],
#        [3.55254272],
#        [2.44739026],
#        [3.0369399 ],
#        [3.06644933],
#        [9.35205676],
#        [3.36540735],
#        [3.48678591],
#        [2.49106972],
#        [4.73424155],
#        [2.26617127],
#        [1.80618349],
#        [3.53291981],
#        [5.69251657],
#        [1.67614899],
#        [3.32388916],
#        [3.0195987 ],
#        [2.51407768],
#        [3.85388369],
#        [9.45057423],
#        [5.21176035],
#        [8.96405601],
#        [2.14020723],
#        [7.21844131],
#        [2.52103869],
#        [1.77878131],
#        [2.2901142 ],
#        [7.43658504],
#        [2.47810143],
#        [5.29261389],
#        [2.14545606],
#        [2.61511704],
#        [9.42425156],
#        [2.26832164],
#        [8.06029475],
#        [5.77278817],
#        [2.90857141],
#        [8.30671611],
#        [5.07291417],
#        [2.33913727],
#        [1.59077089],
#        [2.28432945],
#        [1.72994549],
#        [4.7771736 ],
#        [6.8768482 ],
#        [7.58098648],
#        [1.61263537],
#        [2.08740578],
#        [3.95860275],
#        [6.92806279],
#        [2.78802815],
#        [2.87564675],
#        [2.48683993],
#        [1.60560259],
#        [7.07585182],
#        [1.67898711],
#        [1.59489739],
#        [7.30819256],
#        [2.76894361],
#        [3.62590009],
#        [1.68213479],
#        [2.27286855],
#        [4.87551178],
#        [3.3488229 ],
#        [4.16337388],
#        [3.96653272],
#        [3.21189149],
#        [2.35974203],
#        [2.54457731],
#        [2.57350868],
#        [7.17132591],
#        [1.98569264],
#        [1.76045586],
#        [2.46046175],
#        [1.61578989],
#        [2.3471179 ],
#        [2.8008491 ],
#        [2.14547013],
#        [1.7375144 ],
#        [2.21874644],
#        [1.82050227],
#        [4.47569887],
#        [1.63926937],
#        [1.595508  ],
#        [1.58963143],
#        [1.65892533],
#        [1.64842851],
#        [1.60896658],
#        [2.17455667],
#        [9.43653706],
#        [1.60045649],
#        [2.53248451],
#        [1.6689362 ],
#        [3.46349383],
#        [1.76078027],
#        [2.76060992],
#        [1.94735979],
#        [2.57755529],
#        [6.22426362],
#        [4.10050786],
#        [1.57764822],
#        [3.69958101],
#        [8.77742244],
#        [3.22207324],
#        [2.74793348],
#        [4.83952892],
#        [9.09079059],
#        [6.34573944],
#        [8.50942093],
#        [5.64709163],
#        [1.60882606],
#        [1.58274443],
#        [1.60982271],
#        [8.87901325],
#        [8.39123927],
#        [8.48256705],
#        [2.88469271],
#        [1.86405463],
#        [1.6054788 ],
#        [3.21395932],
#        [3.56410715],
#        [2.34690943],
#        [3.02099377],
#        [7.31178979],
#        [8.66793191],
#        [1.71737975],
#        [2.32329157],
#        [3.14761804],
#        [2.38298233],
#        [2.37743333],
#        [2.52460315],
#        [7.97099218],
#        [5.84766451],
#        [2.96991115],
#        [1.72350285],
#        [3.4105944 ],
#        [2.53923753],
#        [6.04445766],
#        [2.65148176],
#        [6.76522329]])

# %%
yhat = X_poly.dot(lin_reg.coef_.T)+lin_reg.intercept_

# %%
plt.plot(X, y, "b.")
plt.plot(X, yhat, "r.")
plt.axis([-3, 3, 0, 10])
plt.show()

# %%
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

def plot_learning_curves(model, X, y,axlim):
    X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2)
    train_errors, val_errors = [], []
    for m in range(1, len(X_train)):
        model.fit(X_train[:m], y_train[:m])
        y_train_predict = model.predict(X_train[:m])
        y_val_predict = model.predict(X_val)
        train_errors.append(mean_squared_error(y_train[:m], y_train_predict))
        plt.axis(axlim)
        val_errors.append(mean_squared_error(y_val, y_val_predict))
    plt.plot(np.sqrt(train_errors), "r-+", linewidth=2, label="train")
    plt.plot(np.sqrt(val_errors), "b-", linewidth=3, label="val")
    plt.plot

# %%
lin_reg = LinearRegression()
axlim = [0, 80, 0, 3]
plot_learning_curves(lin_reg, X, y, axlim)

# %%
from sklearn.pipeline import Pipeline

polynomial_regression = Pipeline([
        ("poly_features", PolynomialFeatures(degree=10, include_bias=False)),
        ("lin_reg", LinearRegression()),
    ])
axlim = [0, 80, 0, 3]
plot_learning_curves(polynomial_regression, X, y, axlim)

# %%
print("Ridge Regression")
print("Ridge Regression Cost function")
# Out:
# Ridge Regression
# Ridge Regression Cost function

# %%
import matplotlib.pyplot as plt
a = r'J (\theta) =  MSE(\theta) + \alpha \frac{1}{2} \sum_{i=1}^{n} \theta_i^{(2)}'
ax = plt.axes([0,0,0.3,0.3]) #left,bottom,width,height
ax.set_xticks([])
ax.set_yticks([])
ax.axis('off')
plt.text(0.4,0.4,'$%s$' %a,size=30,color="green")
# Out:
# Text(0.4, 0.4, '$J (\\theta) =  MSE(\\theta) + \\alpha \\frac{1}{2} \\sum_{i=1}^{n} \\theta_i^{(2)}$')

# %%
print("Ridge regression closed form solution")
# Out:
# Ridge regression closed form solution

# %%
#Note that the bias term θ0 is not regularized (the sum starts at i = 1, not 0)
import matplotlib.pyplot as plt
a = r'\hat{\theta} =(x^{T} x + \alpha A)^{-1} x^{T}y'
ax = plt.axes([0,0,0.3,0.3]) #left,bottom,width,height
ax.set_xticks([])
ax.set_yticks([])
ax.axis('off')
plt.text(0.4,0.4,'$%s$' %a,size=30,color="green")
# Out:
# Text(0.4, 0.4, '$\\hat{\\theta} =(x^{T} x + \\alpha A)^{-1} x^{T}y$')

# %%
from sklearn.linear_model import Ridge

#

#Regularization strength; must be a positive float. Regularization improves the conditioning of the problem 
#and reduces the variance of the estimates. Larger values specify stronger regularization. Alpha corresponds
#to C^-1 in other linear models such as LogisticRegression or LinearSVC. If an array is passed, penalties are
#assumed to be specific to the targets. Hence they must correspond in number.

#solver = "cholesky"
#‘cholesky’ uses the standard scipy.linalg.solve function to obtain a closed-form solution.

ridge_reg = Ridge(alpha=1, solver="cholesky")
ridge_reg.fit(X, y)
ridge_reg.predict([[1.5]])
# Out:
# array([[5.0057712]])

# %%
#penalty = "l2"

#The penalty (aka regularization term) to be used. Defaults to ‘l2’ which is the standard regularizer for 
#linear SVM models. ‘l1’ and ‘elasticnet’ might bring sparsity to the model (feature selection) not achievable
#with ‘l2’

gd_reg = SGDRegressor(penalty="l2")
sgd_reg.fit(X, y.ravel())
sgd_reg.predict([[1.5]])
# Out:
# array([4.81321288])

# %%
import matplotlib.pyplot as plt
a = r'J (\theta) =  MSE(\theta) + \alpha \sum_{i=1}^{n} |\theta_i|'
ax = plt.axes([0,0,0.3,0.3]) #left,bottom,width,height
ax.set_xticks([])
ax.set_yticks([])
ax.axis('off')
plt.text(0.4,0.4,'$%s$' %a,size=30,color="green")
# Out:
# Text(0.4, 0.4, '$J (\\theta) =  MSE(\\theta) + \\alpha \\sum_{i=1}^{n} |\\theta_i|$')
